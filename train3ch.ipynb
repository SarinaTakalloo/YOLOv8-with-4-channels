# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %% [markdown]
# # RGB with default

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\RGB_Augmented\config.yaml', epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.6 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\RGB_Augmented\config.yaml', epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.6 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGN with default

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\config.yaml', epochs=100, imgsz=640, device = 0)
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\config.yaml', epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.24 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGE with default

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGE\data\config.yaml', epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.7 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGB with lr = 0.1

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\RGB_Augmented\config.yaml', lr0=0.1, epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.7 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGN with lr = 0.1

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\config.yaml', lr0=0.1,epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.7 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGE with lr=0.1

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGE\data\config.yaml', lr0=0.1, epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.7 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGB with batch = 32

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\RGB_Augmented\config.yaml',batch=32, epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.9 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGN with batch = 32

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\config.yaml', batch=32,epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGE with batch = 32

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGE\data\config.yaml', batch=32,epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGB with lr = 0.001

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\RGB_Augmented\config.yaml',lr0=0.001, epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGN with lr = 0.001

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\config.yaml', lr0=0.001,epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # RGE with lr = 0.001

# %%
results = model.train(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGE\data\config.yaml', lr0=0.001,epochs=100, imgsz=640, device = 0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# ...

# %% [markdown]
# # Training with HuggingFace

# %% [markdown]
# ### RGE with HF  --> update: it did not work properly

# %%
results = model.val(data=r'C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\config.yaml', epochs=1, imgsz=640, device = 0)
# Out:
# Ultralytics YOLOv8.0.43  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 11143386 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\test\labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]C:\Users\amalti\.conda\envs\yolo3ch\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# ...

# %% [markdown]
# # Validation on test dataset

# %% [markdown]
# ## RGB lr 0.1

# %%
model = YOLO(r'C:\Users\amalti\Desktop\sarina\YOLOv8-with-4-channels\runs\detect\RGB lr 0.1\weights\best.pt')

# %%
results = model.val(data=r'C:\Users\amalti\Desktop\sarina\RGB_Augmented\config.yaml', conf=0.25,iou=0.6, epochs=100, imgsz=640, device = 0)
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\RGB_Augmented\data\test\labels... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60/60 [00:03<00:00, 18.99it/s]
# val: New cache created: C:\Users\amalti\Desktop\sarina\RGB_Augmented\data\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/4 [00:00<?, ?it/s]C:\Users\amalti\.conda\envs\yolo3ch\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# ...

# %%
model = YOLO(r'C:\Users\amalti\Desktop\sarina\YOLOv8-with-4-channels\runs\detect\RGB lr 0.1\weights\best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\RGB_Augmented\data\val\labels.cache... 300 images, 0 backgrounds, 1 corrupt: 100%|
# val: WARNING  C:\Users\amalti\Desktop\sarina\RGB_Augmented\data\val\images\image650.jpg: ignoring corrupt image/label: could not convert string to float: 'st'
# C:\Users\amalti\.conda\envs\yolo3ch\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,
# ...

# %%
model = YOLO(r'C:\Users\amalti\Desktop\sarina\YOLOv8-with-4-channels\runs\detect\RGB lr 0.1\weights\best.pt')  # load a custom model
model.overrides['conf'] = 0.7  # NMS confidence threshold
# model.overrides['iou'] = 0.45  # NMS IoU threshold
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\RGB_Augmented\data\test\labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60/60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:07<00:00,  1.92s/it]
#                    all         60       1135      0.514       0.16       0.31      0.127
#                healthy         60        401      0.477       0.18      0.302      0.115
#               stressed         60        734      0.551       0.14      0.318      0.138
# Speed: 2.8ms preprocess, 5.0ms inference, 0.0ms loss, 8.0ms postprocess per image
# Results saved to runs\detect\val18
# array([    0.11533,     0.13828])

# %%
model = YOLO(r'C:\Users\amalti\Desktop\sarina\YOLOv8-with-4-channels\runs\detect\RGN lr 0.001\weights\best.pt')  # load a custom model
model.overrides['conf'] = 0.7  # NMS confidence threshold
# model.overrides['iou'] = 0.45  # NMS IoU threshold
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGN\data\test\labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100%|████████
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:05<00:00,  1.45s/it]
#                    all         60       1135      0.144    0.00193     0.0459     0.0124
#                healthy         60        401      0.222    0.00249     0.0601      0.012
#               stressed         60        734     0.0653    0.00136     0.0317     0.0127
# Speed: 1.4ms preprocess, 9.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\detect\val19
# array([   0.012027,    0.012678])

# %%
model = YOLO(r'C:\Users\amalti\Desktop\sarina\YOLOv8-with-4-channels\runs\detect\RGE lr 0.001\weights\best.pt')  # load a custom model
model.overrides['conf'] = 0.7  # NMS confidence threshold
# model.overrides['iou'] = 0.45  # NMS IoU threshold
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGE\data\test\labels... 60 images, 0 backgrounds, 0 corrupt: 100%|██████████| 60
# val: New cache created: C:\Users\amalti\Desktop\sarina\Spectral_Augmented\RGE\data\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:07<00:00,  1.91s/it]
#                    all         60       1135      0.414    0.00193     0.0883     0.0248
#                healthy         60        401      0.643    0.00249      0.129     0.0258
#               stressed         60        734      0.184    0.00136     0.0476     0.0238
# Speed: 1.7ms preprocess, 4.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs\detect\val20
# array([   0.025812,    0.023781])

# %%
model = YOLO('yolov8n.pt')

# %%
model.overrides['conf'] = 0.7  # NMS confidence threshold
# model.overrides['iou'] = 0.45  # NMS IoU threshold
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco.yaml' images not found , missing path 'C:\Users\amalti\Desktop\sarina\datasets\coco\val2017.txt'
# ...
# 100%|██████████████████████| 169M/169M [00:00<00:00, 308MB/s]
# Unzipping C:\Users\amalti\Desktop\sarina\datasets\coco2017lab
# --------------------------------------------------------------
# KeyboardInterrupt            Traceback (most recent call last)
# Cell In[8], line 4
#       1 model.overrides['conf'] = 0.7  # NMS confidence threshold
#       2 # model.overrides['iou'] = 0.45  # NMS IoU threshold
#       3 # Validate the model
# ----> 4 metrics = model.val()  # no arguments needed, dataset and settings remembered
#       5 metrics.box.map  # map50-95
#       6 metrics.box.map50  # map50
#
# ...

# %%
model = YOLO(r'C:\Users\amalti\Desktop\sarina\runs\detect\rgn defaults\weights\last.pt')  # load a custom model
model.overrides['conf'] = 0.7  # NMS confidence threshold
# model.overrides['iou'] = 0.45  # NMS IoU threshold
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22  Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA A40-12Q, 12288MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\amalti\Desktop\sarina\Spectral_Augment
#                  Class     Images  Instances      Box(P
#                    all         60       1135          0          0          0          0
# Speed: 3.0ms preprocess, 5.3ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to runs\detect\val25
# array([], dtype=float64)

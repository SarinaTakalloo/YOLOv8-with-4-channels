# %%
# %pwd
# Out:
# 'C:\\Users\\amalti\\Desktop\\sarina'

# %%
from dataset_prepration import combine_channels

# %%
green_folder = r'Spectral_Augmented/Green_Channel/Train_Images'
red_folder = r'Spectral_Augmented/Red_Channel/Train_Images'
near_infrared_folder = r'Spectral_Augmented/Near_Infrared_Channel/Train_Images'
red_edge_folder = r'Spectral_Augmented/Red_Edge_Channel/Train_Images'
output_folder = r'Spectral_Augmented/RGE/data/train/images'


green_folder_t = r'Spectral_Augmented/Green_Channel/Test_Images'
red_folder_t = r'Spectral_Augmented/Red_Channel/Test_Images'
near_infrared_folder_t = r'Spectral_Augmented/Near_Infrared_Channel/Test_Images'
red_edge_folder_t = r'Spectral_Augmented/Red_Edge_Channel/Test_Images'
output_folder_t = r'Spectral_Augmented/RGE/data/test/images'
combine_channels('RGE', green_folder, red_folder, near_infrared_folder, red_edge_folder, output_folder)
combine_channels('RGE', green_folder_t, red_folder_t, near_infrared_folder_t, red_edge_folder_t, output_folder_t)

# %%
from dataset_prepration import  move_matching_labels

# %%
base_folder =  r'Spectral_Augmented/RGE/data/val/labels'
origin_folder = r'Spectral_Augmented/RGE/data/train/images'
destination_folder = r'Spectral_Augmented/RGE/data/val/images'
move_matching_labels(base_folder, origin_folder, destination_folder)
# Out:
# Moved Image_08.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_09.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1002.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1004.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1008.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1010.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1011.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1016.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1032.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1035.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1036.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1037.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1042.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1043.tif to Spectral_Augmented/RGE/data/val/images
# Moved Image_1044.tif to Spectral_Augmented/RGE/data/val/images
# ...
